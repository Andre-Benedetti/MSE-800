# %%
from random import randint

# %%
# example 1
for i in range(1, 20):
    if i == 20:
        print(f"You got it!")

# Describe the problem - Write your answers as comments:
# 1. what is the loop doing? The loop is iterating through the numbers 1 to 19, and checking if the current number (i) is equal to 20. Since i will never be equal to 20, the condition will never be true, and "You got it!" will never be printed.  
# 2. When is the function meant to print "You got it!"? The function is meant to print "You got it!" when the variable i is equal to 20. However, since the loop only iterates from 1 to 19, this condition will never be met, and the message will never be printed.
# 3. What are your assumptions about the value of i? The assumption is that i will be in the range 1 inclusive to 20 exclusive, so it will never reach 20.

# %%
# example 2
dice_images = ["1", "2", "3", "4", "5", "6"]
dice_num = randint(1, 6)
print(dice_images[dice_num])
#randiant uses the index of the list, so it will never reach 6 as the "6" has a 5 as index (6 elements -> index from 0 to 5), and will throw an error.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 4
#       2 dice_images = ["1", "2", "3", "4", "5", "6"]
#       3 dice_num = randint(1, 6)
# ----> 4 print(dice_images[dice_num])
#       5 #randiant uses the index of the list, so it will never reach 6 as the "6" has a 5 as index (6 elements -> index from 0 to 5), and will throw an error.
#
# IndexError: list index out of range

# %%
# example 3
year = int(input("What is your year of birth?"))

if year > 1980 and year < 1994:
    print("You are a Millennial")
elif year > 1994:
    print("You are a Gen Z")

#the problem is that the program is not considering who was born before 1980 and who was born in 1994

# %%
# example 4
word_per_page = 0
pages = int(input("Number of pages: "))
word_per_page == int(input("Number of words per page: ")) #the usage of "==" is for comparison, not for assignment, making word_per_page always 0.
total_words = pages * word_per_page

print(f"We have {total_words} in total.")
# Out:
# We have 0 in total.

# %%
# example 5
def add(a1, a2):
    return a1 + a2

def mutate(a_list):
    b_list = []
    new_item = 0
    for item in a_list:
        new_item = item * 2
        new_item += randint(1, 3)
        new_item = add(new_item, item)
    b_list.append(new_item) #this line is outside the for loop, so it will only append the last new_item calculated.

    print(b_list)

# %%
a_demo_list = [1, 2, 3, 5, 1, 21, 4, 35]
mutate(a_demo_list)
# Out:
# [107]
