# %%
def odd_or_even(number):
    if number % 2 = 0: #it should use "==" for comparison, not ""
        return "This is an even number."
    else:
        return "This is an odd number."

# %%
odd_or_even(0)

# %%
# This is how you work out whether if a particular year is a leap year.
# - on every year that is divisible by 4 with no remainder
# - except every year that is evenly divisible by 100 with no remainder
# - unless the year is also divisible by 400 with no remainder
def is_leap(year):
    if year % 4 == 0:
        if year % 100 == 0:
            if year % 4000 == 0:# This should be 400, not 4000
                return True
            else:
                return False
        else:
            return True
    else:
        return False

# %%
is_leap(2000)
print(is_leap(2000))
# Out:
# True

# %%
# Target is the number up to which we count
# The code needs to print the solution to the FizzBuzz game.   
# - Your program should print each number from 1 to x where x is the input number.
# - However when the number is divisible by 3 then instead of printing the number it should print "Fizz".   
# - When the number is divisible by 5, then instead of printing the number it should print "Buzz". 
# - And if the number is divisible by both 3 and 5 e.g. 15 then instead of the number it should print "FizzBuzz".
def fizz_buzz(target):
    for number in range(1, target):
        if number % 3 == 0 or number % 5 == 0: # This should be an "and", not an "or"
            print(f"{number} is a FizzBuzz") #this should only print "FizzBuzz" not the number
        if number % 3 == 0:
            print(f"{number} is a Fizz")#this should only print "FIZZ" not the number
        if number % 5 == 0:
            print(f"{number} is a Buzz")#this should only print "Buzz" not the number
        else:
            print(number)

# %%
fizz_buzz(50)
# Out:
# 1
# 2
# 3 is a FizzBuzz
# 3 is a Fizz
# 3
# 4
# 5 is a FizzBuzz
# 5 is a Buzz
# 6 is a FizzBuzz
# 6 is a Fizz
# 6
# 7
# 8
# 9 is a FizzBuzz
# 9 is a Fizz
# 9
# 10 is a FizzBuzz
# 10 is a Buzz
# 11
# 12 is a FizzBuzz
# 12 is a Fizz
# 12
# 13
# 14
# 15 is a FizzBuzz
# 15 is a Fizz
# 15 is a Buzz
# 16
# 17
# 18 is a FizzBuzz
# 18 is a Fizz
# 18
# 19
# 20 is a FizzBuzz
# 20 is a Buzz
# 21 is a FizzBuzz
# 21 is a Fizz
# 21
# 22
# 23
# 24 is a FizzBuzz
# 24 is a Fizz
# 24
# 25 is a FizzBuzz
# 25 is a Buzz
# 26
# 27 is a FizzBuzz
# 27 is a Fizz
# 27
# 28
# 29
# 30 is a FizzBuzz
# 30 is a Fizz
# 30 is a Buzz
# 31
# 32
# 33 is a FizzBuzz
# 33 is a Fizz
# 33
# 34
# 35 is a FizzBuzz
# 35 is a Buzz
# 36 is a FizzBuzz
# 36 is a Fizz
# 36
# 37
# 38
# 39 is a FizzBuzz
# 39 is a Fizz
# 39
# 40 is a FizzBuzz
# 40 is a Buzz
# 41
# 42 is a FizzBuzz
# 42 is a Fizz
# 42
# 43
# 44
# 45 is a FizzBuzz
# 45 is a Fizz
# 45 is a Buzz
# 46
# 47
# 48 is a FizzBuzz
# 48 is a Fizz
# 48
# 49
